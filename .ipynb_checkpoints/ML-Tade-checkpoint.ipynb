# %% [markdown]
# ML-Supervised Learning Project-1

# %% [markdown]
# Step 1: Data Cleaning & Preprocessing

# %% [markdown]
# The first step is Load the data & understand the data very well.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
# Load dataset
df = pd.read_csv("C:/Users/TadeleBizuye/OneDrive - esxethiopia/Desktop/Laabza/Baacumen/M_6 Machine Learning/train.csv")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 1     5K0N3X1            City   Premium Membership   2017-08-28
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
#
#   joined_through_referral referral_id  ... avg_time_spent  \
# 0                      No    xxxxxxxx  ...         300.63
# ...

# %%
df.describe()
# Out:
#                 age  days_since_last_login  avg_time_spent  \
# count  36992.000000           36992.000000    36992.000000
# mean      37.118161             -41.915576      243.472334
# std       15.867412             228.819900      398.289149
# min       10.000000            -999.000000    -2814.109110
# 25%       23.000000               8.000000       60.102500
# 50%       37.000000              12.000000      161.765000
# 75%       51.000000              16.000000      356.515000
# max       64.000000              26.000000     3235.578521
#
#        avg_transaction_value  points_in_wallet  churn_risk_score
# count           36992.000000      33549.000000      36992.000000
# mean            29271.194003        686.882199          3.463397
# std             19444.806226        194.063624          1.409661
# min               800.460000       -760.661236         -1.000000
# 25%             14177.540000        616.150000          3.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36992 entries, 0 to 36991
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_id                   36992 non-null  object
#  1   Name                          36992 non-null  object
#  2   age                           36992 non-null  int64
#  3   gender                        36992 non-null  object
#  4   security_no                   36992 non-null  object
#  5   region_category               31564 non-null  object
#  6   membership_category           36992 non-null  object
#  7   joining_date                  36992 non-null  object
#  8   joined_through_referral       36992 non-null  object
#  9   referral_id                   36992 non-null  object
#  10  preferred_offer_types         36704 non-null  object
#  11  medium_of_operation           36992 non-null  object
# ...

# %% [markdown]
# Step 1: Data Cleaning & Preprocessing
#
#  1.1 Handling Missing Data)

# %%
df["churn_risk_score"].value_counts() # This is our tareget variable.
# Out:
# churn_risk_score
#  3    10424
#  4    10185
#  5     9827
#  2     2741
#  1     2652
# -1     1163
# Name: count, dtype: int64

# %%
# To check the missing values
df.isnull().sum()
# Out:
# customer_id                        0
# Name                               0
# age                                0
# gender                             0
# security_no                        0
# region_category                 5428
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# referral_id                        0
# preferred_offer_types            288
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                3443
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %%
# To know how many data sets are missed. the first .sum() indicates coloumn & the second .sum() indicates No of columns.
pd.isnull(df).sum().sum() # As we can see in the output there are 9159 missed values. so we need to fill the missing values or remove it
# Out:
# 9159

# %% [raw]
#  Handling Missing Data
# There are various methods to handle missing values in our dataset depending on the nature of the data and the feature’s importance:
# These are
#  1. Dropping Missing Values: This method is suitable when only a small portion of data is missing, and the feature is not essential to the analysis.
# {
# # Drop rows with missing values
# df = df.dropna()
# # OR drop specific columns with large missing values
# df = df.drop(columns=['region_category', 'preferred_offer_types', & 'points_in_wallet'])  # Example for columns with too many missing values
# # We use this method, When the number of missing values is low, or the specific feature is not critical for analysis.
# }
#
# 2. Imputation for Numerical Columns
# Mean/Median Imputation: For numerical columns like points_in_wallet, we can impute missing values with the mean or median of the column.
# {
# # Using median for skewed data
# df['points_in_wallet'].fillna(df['points_in_wallet'].median(), inplace=True)
# # Using mean for normally distributed data
# df['points_in_wallet'].fillna(df['points_in_wallet'].mean(), inplace=True)
# }
# We use this method,When the missing values are randomly distributed and the feature is essential.&
# Median is preferred for skewed data, while mean is used for normally distributed data.
#
# 3. Imputation for Categorical Columns
# Mode Imputation: For categorical columns like region_category, we can fill missing values with the most frequent value (mode).
# {
# df['region_category'].fillna(df['region_category'].mode()[0], inplace=True)
# }
# We use this method, When the missing values are random and the category distribution is not highly imbalanced.
#
# 4. Filling with a Specific Value
# For some features, it makes sense to fill missing values with a constant value, such as "Unknown" or 0.
# {
# # Fill missing categorical values with 'Unknown'
# df['preferred_offer_types'].fillna('Unknown', inplace=True)
# # Fill missing numerical values with 0 (if appropriate)
# df['points_in_wallet'].fillna(0, inplace=True)
# }
# We use this method, When a missing value can indicate a meaningful category like Unknown, or 0 has a logical meaning for the feature.
#
# 5. Imputation Using Predictive Models (Advanced)
# If the column with missing values is important and strongly correlated with other features, we can use a predictive model (such as a regression model) to predict missing values.
# "This type of handling missing values is very complex for me!
# Missed Coulumns:-
#  "region_category",
#  "preferred_offer_types" &
#  "points_in_wallet",
#
#
# Dessision:
# 1. As we have seen, the Column "region_category" & "points_in_wallet" have many missing values (5428) & (3443) & those features are very critical for analysis so we would not drop it! insted, removing of only missed values is prefered.
#
# 2. As we can see in below column "preferred_offer_types" , the missing values are random and the category distribution is highly balanced.
# so we need to use the third method.

# %%
df["preferred_offer_types"].value_counts()
# Out:
# preferred_offer_types
# Gift Vouchers/Coupons       12349
# Credit/Debit Card Offers    12274
# Without Offers              12081
# Name: count, dtype: int64

# %%
df = df[df["region_category"].notnull()]
df = df[df["points_in_wallet"].notnull()]
df.isnull().sum()
# Out:
# customer_id                       0
# Name                              0
# age                               0
# gender                            0
# security_no                       0
# region_category                   0
# membership_category               0
# joining_date                      0
# joined_through_referral           0
# referral_id                       0
# preferred_offer_types           217
# medium_of_operation               0
# internet_option                   0
# last_visit_time                   0
# days_since_last_login             0
# avg_time_spent                    0
# avg_transaction_value             0
# avg_frequency_login_days          0
# points_in_wallet                  0
# used_special_discount             0
# offer_application_preference      0
# past_complaint                    0
# complaint_status                  0
# feedback                          0
# churn_risk_score                  0
# dtype: int64

# %% [markdown]
# As we  can see in the above only column  "preferred_offer_types" has a missing values so we need to adjust it.

# %%
df['preferred_offer_types'].fillna(df['preferred_offer_types'].mode()[0], inplace=True)
df.isnull().sum()
# Out:
# customer_id                     0
# Name                            0
# age                             0
# gender                          0
# security_no                     0
# region_category                 0
# membership_category             0
# joining_date                    0
# joined_through_referral         0
# referral_id                     0
# preferred_offer_types           0
# medium_of_operation             0
# internet_option                 0
# last_visit_time                 0
# days_since_last_login           0
# avg_time_spent                  0
# avg_transaction_value           0
# avg_frequency_login_days        0
# points_in_wallet                0
# used_special_discount           0
# offer_application_preference    0
# past_complaint                  0
# complaint_status                0
# feedback                        0
# churn_risk_score                0
# dtype: int64

# %% [markdown]
# Waw!
#
# Now All missing values are Handeled
#
# All Columns in our data have equal number of rows(28,590)!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28590 entries, 0 to 36991
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_id                   28590 non-null  object
#  1   Name                          28590 non-null  object
#  2   age                           28590 non-null  int64
#  3   gender                        28590 non-null  object
#  4   security_no                   28590 non-null  object
#  5   region_category               28590 non-null  object
#  6   membership_category           28590 non-null  object
#  7   joining_date                  28590 non-null  object
#  8   joined_through_referral       28590 non-null  object
#  9   referral_id                   28590 non-null  object
#  10  preferred_offer_types         28590 non-null  object
#  11  medium_of_operation           28590 non-null  object
# ...

# %% [markdown]
# 1.2 Data Type Correction

# %%
#Data Type Correction

# Convert 'joining_date' to datetime format
df['joining_date'] = pd.to_datetime(df['joining_date'], format='%Y-%m-%d')


# Convert 'last_visit_time' to time format (Hour : Minute: Second)
df['last_visit_time'] = pd.to_datetime(df['last_visit_time'], format='%H:%M:%S').dt.time

# Convert 'avg_frequency_login_days' to numerical (float), 
df['avg_frequency_login_days'] = pd.to_numeric(df['avg_frequency_login_days'], errors='coerce')

# %% [markdown]
# 1.3 Encoding Categorical Variables

# %%
# Label Encoding for binary categorical features
label_encoder = LabelEncoder()
df['gender'] = label_encoder.fit_transform(df['gender'])  # e.g., Male=1, Female=0
df['joined_through_referral'] = label_encoder.fit_transform(df['joined_through_referral'])  # Yes=1, No=0
df['used_special_discount'] = label_encoder.fit_transform(df['used_special_discount'])  # Yes=1, No=0
df['offer_application_preference'] = label_encoder.fit_transform(df['offer_application_preference'])  # Yes=1, No=0
df['past_complaint'] = label_encoder.fit_transform(df['past_complaint'])  # Yes=1, No=0

# One-Hot Encoding for other categorical features( i.e more than two categories)
#columns that needs to be encoding=['region_category', 'membership_category', 'preferred_offer_types', 'medium_of_operation', 'internet_option', 'complaint_status']

# Dear Teams,  Add this OneHot Encoder!!

# %%
df.describe()
# Out:
#                 age        gender                   joining_date  \
# count  28590.000000  28590.000000                          28590
# mean      37.088213      0.501049  2016-07-04 00:50:22.035676672
# min       10.000000      0.000000            2015-01-01 00:00:00
# 25%       23.000000      0.000000            2015-09-30 00:00:00
# 50%       37.000000      0.000000            2016-07-05 00:00:00
# 75%       51.000000      1.000000            2017-04-07 00:00:00
# max       64.000000      2.000000            2017-12-31 00:00:00
# std       15.890970      0.503007                            NaN
#
#        joined_through_referral  days_since_last_login  avg_time_spent  \
# count             28590.000000           28590.000000    28590.000000
# mean                  1.277160             -42.527807      243.529133
# min                   0.000000            -999.000000    -2814.109110
# 25%                   1.000000               8.000000       59.802500
# ...

# %%
df.head()
# Out:
#                             customer_id              Name  age  gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18       0
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44       0
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37       1
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31       0
# 5  fffe43004900440036003300320035003300    Leslie Browder   13       1
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
# 5     PSG1LGF            City      Gold Membership   2016-01-08
#
#    joined_through_referral referral_id  ... avg_time_spent  \
# 0                        1    xxxxxxxx  ...         300.63
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28590 entries, 0 to 36991
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_id                   28590 non-null  object
#  1   Name                          28590 non-null  object
#  2   age                           28590 non-null  int64
#  3   gender                        28590 non-null  int32
#  4   security_no                   28590 non-null  object
#  5   region_category               28590 non-null  object
#  6   membership_category           28590 non-null  object
#  7   joining_date                  28590 non-null  object
#  8   joined_through_referral       28590 non-null  int32
#  9   referral_id                   28590 non-null  object
#  10  preferred_offer_types         28590 non-null  object
#  11  medium_of_operation           28590 non-null  object
# ...

# %% [markdown]
# 1.4 Outlier Detection & Handling

# %% [raw]
# Detect and handle outliers in avg_transaction_value and points_in_wallet using IQR (Interquartile Range) or Z-score.

# %%
continues_variables = df.select_dtypes(include = ['float64', 'int64'])
plt.figure(figsize=(15, 10))
for i, column in enumerate(continues_variables):
    plt.subplot(4, 3, i + 1)
    sns.boxplot(x=continues_variables[column])
    plt.title(f'Box Plot of {column}')
    plt.xlabel(column)

plt.tight_layout()
plt.show();

# %%
continues_variables = continues_variables.apply(lambda x: x.clip(lower = x.dropna().quantile(0.01), 
                                                         upper = x.quantile(0.95)))

# %%
plt.figure(figsize=(15, 10))
for i, column in enumerate(continues_variables):
    plt.subplot(4, 3, i + 1)
    sns.boxplot(x=continues_variables[column])
    plt.title(f'Box Plot of {column}')
    plt.xlabel(column)

plt.tight_layout()
plt.show();

# %% [markdown]
# 1.5 Feature Engineering

# %%
# 1.5 Feature Engineering
df['customer_tenure'] = (pd.to_datetime('today') - df['joining_date']).dt.days
df['engagement_score'] = df['days_since_last_login'] / df['avg_time_spent']
# Example of engagement-based feature: active login days (from 'days_since_last_login')
df['active_days'] = 30 / df['days_since_last_login']  # Assuming logins per month
# Verify new features
print(df[['customer_tenure','engagement_score', 'active_days']].head())
# Out:
#    customer_tenure  engagement_score  active_days
# 0             2607          0.056548     1.764706
# 2             2886          0.027123     2.142857
# 3             2899          0.206495     2.727273
# 4             2581          0.176788     1.500000
# 5             3194          0.053042     1.304348
